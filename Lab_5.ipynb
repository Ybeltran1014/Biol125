# %% [markdown]
# #Lab 5 Auditory and Visual Reaction Time

# %% [markdown]
# #Purpose

# %% [markdown]
# To determine visual and auditory reaction times.

# %% [markdown]
# # Procedure

# %% [markdown]
# I followed the instructions on the websites to determine visual and auditory reactions. The website for the auditory test was benchmark and playback auditory. For vision, I followed the instructions by clicking on the screen when the green color came up. I would obtain ms of the reaction time for a total of 10 times.For auditory, I followed the instructions and pressed the space bar when I heard the sound. The test provided me with the ms of the auditory reaction time for a total of 10 times.

# %% [markdown]
# # Results

# %%
import matplotlib.pyplot as plt

# %%
VIS1_MEAN = 265.1
AUD1_MEAN = 235.9
VIS1_STD = 29.15
AUD1_STD = 40.33

# %%
# build a bar plot
plt.bar(['Person 4 Visual', 'Person 4 Auditory'],[VIS1_MEAN, AUD1_MEAN], yerr=[VIS1_STD, AUD1_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual vs. Auditory')

# %% [markdown]
# # Discussion

# %% [markdown]
# This test hepled me understand the difference in reaction time between the vision and audio.
