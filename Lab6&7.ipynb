# %% [markdown]
# # Lab 6 & 7
# ##Sensory Physiology

# %% [markdown]
# ### **Purpose**
# Performed a series of excercises that measure the capabilities of the sensory systems. Cutaneous, olfactory,auditory, proprioceptive, and visual systems were examined to observe the basic principles of sensory physiology.

# %% [markdown]
# ### **Procedures**

# %% [markdown]
# Tests of cutaneous sensation
#
# A-1:Two-point discrimination
#
# 1. With partner's eyes closed, applied two cliper pinpoints as closely together as possible on partner's skin on the palm of her hand.
# 2. Removed the pins and moved them 1 millimeter apart. Reapplied the caliper points to partner's skin. Repeated the procedure until partner was able to discriminate two distinct caliper points.
# 3. Recorded the distance between pins at which partner could discriminate two seperate caliper points.
# 4. Recorded results from the following areas
#
# a. palm of hand
#
# b. back of hand
#
# c. fingertip
#
# d. back of neck

# %% [markdown]
# A-2:Accommodation of thermoreceptors
#
# 1. Placed left fingers in 15C water and right fingers in warm water (37C) and recorded sensation of each. Kept hands immersed for 2 minutes.
# 2. After 2 minutes, described the sensation in each hand.
# 3. Removed hands promptly and placed them both in 25C water.Described the immediate sensation in each hand.

# %% [markdown]
# 6/7-B: Olfactory adaptation
# 1. Blocked left nostril. Held a bottle of camphor oil under nose until can no longer detect the camphor.Recorded the adaption time.
# 2. Removed the camphor and placed the bottles of cloves, then peppermint oil under nose. Distinguished the smells of cloves and peppermint oil.
# 3. Held a bottle of camphor oil under nose again until the smell is no longer recognized.Recorded the second adaptation time.
# 4. Unblocked the left nostrile and determined if camphor is detected

# %% [markdown]
# C-1: Tuning fork test
# 1. Plug your left ear with cotton or hold your hand over it and test the right ear.
# 2. Hold the handle of a vibrating tuning fo
# rk
# to the right mastoid process.
# 3. When the sound disappears, move the fork n
# ear the external auditory canal
# .
# 4. Reappearance of the sound indicates
# no
# middle ear damage.
# 5. Repeat the test with your left ear
# 6. Record the results for each ear.

# %% [markdown]
# E-4: Color vision 2-Color blindness test
#
# 1.Obtain the Ichikawa color
# blindness charts.
#
# 2.Attempt to read the numbers of each pattern on the
# test panels. (There are some
# “practice” panels before the actual test panels begin.)
#
# 3.After the first 10 test panels, if your score indicates color blindness, continue with the next five test panels to determine which colordeficiency exists.
#
# 4.Record your results on the worksheet on page 46

# %% [markdown]
# E-5: Perimetry
# 1. Seat yourself before the perimeter board with your right eye at the edge of the semicircle. Cover your left eye. Stare at the center line.
# 2. Your lab partner will introduce several different colored blocks into your field of vision.Identify these blocks by color. Do not take your eye from the center of the chart or uncover your left eye.
# 3. Your partner will record the degree at which the colors were discriminated on the perimetry score sheet on page 47.
# 4. Repeat these procedures for each block for both the horizontal and vertical perimetry charts. Record the data and connect the same colored dots to form an outline of coneplacement of your right eye on your data sheet.
# 5.Explain these results in regards to cone placement in your retina.

# %% [markdown]
# ## Results

# %%
import pandas as pd

# %%
pd.read_excel('/content/drive/MyDrive/Lab_6.7.xlsx')
# Out:
#               A-1: Two -point discrimination           Unnamed: 1
# 0                                palmof hand                13 mm
# 1                               back of hand                18 mm
# 2                                  fingertip                 1 mm
# 3                         outer edge of lips              skipped
# 4                               back of neck                36 mm
# 5       A-2: Accomodation of thermoreceptors                  NaN
# 6               left hand: numbness and pain   right hand: normal
# 7           left hand:warm(no more numbness)      right hand:cold
# 8                6/7 B: Olfactory Adaptation                  NaN
# 9                             Time 1: 1.3sec                  NaN
# 10                            Time 2: 30 sec                  NaN
# 11                      C-1:Tuning fork test                  NaN
# 12               Showed no middle ear damage                  NaN
# ...

# %% [markdown]
# ## Discussion

# %% [markdown]
# A-1: Two-point discrimination
# The results from the experiment show how the area with the most tactile sensors sensed the two-points faster than the areas without the tactile sensors. Since the fingertip has the most sensors it sensed the difference much faster than the other areas.
#
# A-2: Accomodation of thermoreceptors
# At the beginning of the experiment the hands reacted to the cold and warm water. The left fingers felt cold and it starte to hurt from how cold the water was. The right fingers felt warm. When both hands were placed in the room temperature water the sensors of the fingers reacted to the change in temperature quickly.The fingers on my left hand that were in the ice cold water felt really warm when placed into the room temperature water and the fingers on my right hand felt cold.
#
# 6/7 Olfactory Adaptation
# It took a little longer for me to adapt to the smell of the essential oil than it did for me to react to the change of scent the second time.
#
# C-1: Tuning fork test
# The results showed no middle ear damage. I was not expecting the test to show otherwise.
#
# E-4: Color-blindness test
# The results of the test show that I do not have any color-blindness.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# It was interesting to test our senses with the different exercises. I was not surprised to see that I did not show any color-blindness or middle ear damage. The olfactory adaptation test was interesting to me. It was interesting to see how long it took for me to only smell the oil and then to see how quickly my senses reacted to the change.
